# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker

# %%
MBDF_global_tot = [255.81756042517168, 238.3110723745247, 187.04522080336156, 145.87709887913854, 128.87176652018945]
MBDF_global_tot_err = [90, 71, 35, 15,  6]

MBDF_local_tot = [158.77643401153085, 152.8612980389271, 132.25907560704897, 112.9931195415939, 108.77700272383011]
MBDF_local_tot_err = [ 9, 12,  8,  4,  2]

CSE_tot = [265.1522941669745, 221.36684164535646, 151.45402955341947, 121.51791171033182, 113.11589532668991]
CSE_tot_err = [107,  67,  27,  10,   5]
CSE_lexi_tot = [256.6672601020174, 229.6715878128923, 157.94411546448603, 122.64413184579045, 111.47560640727701]
CSE_lexi_tot_err = [93, 73, 28, 10,  5]
CSE_lexi_xG_tot = [262.82399584109135, 228.87500494207663, 157.87721689734246, 123.3167641231535, 113.26775978904487]
CSE_lexi_xG_tot_err = [95, 71, 28, 10,  5]

IDM_tot = [334.0240581173795, 257.23725798310795, 156.14952268380358, 123.18450316614124, 110.69688628850649]
IDM_lexi_tot = [484.5938810046895, 284.0641367931712, 163.34279712646494, 121.82723707244405, 108.29852748931927]
IDM_lexi_tot_err = [72, 73, 26, 10,  6]
IDM_lexi_xG_tot = [417.3895020011381, 273.45456889847054, 159.04228694588474, 121.40919132480535, 110.34241159728586]

# %%
np.array([247.1076878001279, 187.23374614462693, 60.24845670985051, 22.19838318804007, 14.366599995406544]/np.sqrt(5)).astype(int)
# Out:
# array([110,  83,  26,   9,   6])

# %%
# CSE_lexi
# IDM_lexi
# MBDF_global
# MBDF_local
# Second order alchemy

plt.figure(figsize=(12, 8))


x = [80, 160, 320, 640, 1280]
second_order_alchemy = [145.62546462994108] * 5

linewidth = 3
markersize = 15

plt.plot(x, MBDF_global_tot, label='MBDF Global', marker='*', linestyle='--', linewidth=linewidth, markersize=markersize)
plt.fill_between(x, 
                 np.array(MBDF_global_tot)-np.array(MBDF_global_tot_err), 
                 np.array(MBDF_global_tot)+np.array(MBDF_global_tot_err), alpha=0.2)

plt.plot(x, MBDF_local_tot, label='MBDF Local', marker='*', linestyle='--', linewidth=linewidth, markersize=markersize)
plt.fill_between(x, 
                 np.array(MBDF_local_tot)-np.array(MBDF_local_tot_err), 
                 np.array(MBDF_local_tot)+np.array(MBDF_local_tot_err), alpha=0.2)

plt.plot(x, CSE_lexi_tot, label='CSE-lexi', marker='*', linestyle='-', linewidth=linewidth, markersize=markersize)
plt.fill_between(x, 
                 np.array(CSE_lexi_tot)-np.array(CSE_lexi_tot_err), 
                 np.array(CSE_lexi_tot)+np.array(CSE_lexi_tot_err), alpha=0.2)

plt.plot(x, IDM_lexi_tot, label='IDM-lexi', marker='*', linestyle='-', linewidth=linewidth, markersize=markersize, color='#9467bd')
plt.fill_between(x, 
                 np.array(IDM_lexi_tot)-np.array(IDM_lexi_tot_err), 
                 np.array(IDM_lexi_tot)+np.array(IDM_lexi_tot_err), alpha=0.2)

plt.plot(x, second_order_alchemy, label="Second order alchemy", marker='', linestyle='-', linewidth=linewidth, markersize=markersize, color='red')

# plt.title('Learning curve for BN-Doped Coronene molecule total energy prediction')
plt.xlabel('Training Size')
plt.ylabel('Average MAE [mHa]')
plt.legend()

plt.xscale('log', base=2)
plt.yscale('log', base=10)
xticks = [80, 160, 320, 640, 1280]
yticks = [100, 120, 150, 200, 300, 400, 600]
plt.xticks(xticks, labels = xticks)
plt.yticks(yticks, labels = yticks)

plt.savefig('../graph/[Coronene] Total Energy.png', dpi=300)
plt.show()

# %%
color_cycle = plt.rcParams['axes.prop_cycle'].by_key()['color']

# Display the colors
print("Default color cycle:", color_cycle)
# Out:
# Default color cycle: ['#1f77b4', '#ff7f0e', '#2ca02c', '#d62728', '#9467bd', '#8c564b', '#e377c2', '#7f7f7f', '#bcbd22', '#17becf']

# %%
MBDF_global_elec = [340.00592136356926, 307.9253720518421, 246.35443344791176, 227.175577809917, 207.37412665538636]
MBDF_global_elec_err = [73, 62, 32, 20,  4]

MBDF_local_elec = [1780.4674480947842, 1393.2726950409804, 1087.905958069777, 801.72746788064, 610.8146906356312]
MBDF_local_elec_err = [12, 15, 11, 10,  7]

CSE_lexi_elec = [7974.643539694208, 7055.292335672233, 6685.1696756609845, 6589.8450190646, 6518.547696953229]
CSE_lexi_elec_err = [270, 218, 126,  84,  84]

IDM_lexi_elec = [8195.405953469864, 7253.669208526226, 6712.898131065595, 6637.550950336366, 6511.504601819956]
IDM_lexi_elec_err = [186, 219, 109,  73,  77]

# %%
# CSE_lexi
# IDM_lexi
# MBDF_global
# MBDF_local
# Second order alchemy

plt.figure(figsize=(12, 8))


x = [80, 160, 320, 640, 1280]
second_order_alchemy = [145.62546462994108] * 5

linewidth = 3
markersize = 15

plt.plot(x, MBDF_global_elec, label='MBDF Global', marker='*', linestyle='--', linewidth=linewidth, markersize=markersize)
plt.fill_between(x, 
                 np.array(MBDF_global_elec)-np.array(MBDF_global_elec_err), 
                 np.array(MBDF_global_elec)+np.array(MBDF_global_elec_err), alpha=0.2)

plt.plot(x, MBDF_local_elec, label='MBDF Local', marker='*', linestyle='--', linewidth=linewidth, markersize=markersize)
plt.fill_between(x, 
                 np.array(MBDF_local_elec)-np.array(MBDF_local_elec_err), 
                 np.array(MBDF_local_elec)+np.array(MBDF_local_elec_err), alpha=0.2)

plt.plot(x, CSE_lexi_elec, label='CSE-lexi', marker='*', linestyle='-', linewidth=linewidth, markersize=markersize)
plt.fill_between(x, 
                 np.array(CSE_lexi_elec)-np.array(CSE_lexi_elec_err), 
                 np.array(CSE_lexi_elec)+np.array(CSE_lexi_elec_err), alpha=0.2)

plt.plot(x, IDM_lexi_elec, label='IDM-lexi', marker='*', linestyle='-', linewidth=linewidth, markersize=markersize, color='#9467bd')
plt.fill_between(x, 
                 np.array(IDM_lexi_elec)-np.array(IDM_lexi_elec_err), 
                 np.array(IDM_lexi_elec)+np.array(IDM_lexi_elec_err), alpha=0.2)

plt.plot(x, second_order_alchemy, label="Second order alchemy", marker='', linestyle='-', linewidth=linewidth, markersize=markersize, color='red')

# plt.title('Learning curve for BN-Doped Coronene molecule total energy prediction')
plt.xlabel('Training Size')
plt.ylabel('Average MAE [mHa]')
plt.legend()

plt.xscale('log', base=2)
plt.yscale('log', base=10)
xticks = [80, 160, 320, 640, 1280]
yticks = [100, 200, 500, 1000, 2000, 5000, 10000]
plt.xticks(xticks, labels = xticks)
plt.yticks(yticks, labels = yticks)

plt.savefig('../graph/[Coronene] Electronic Energy.png', dpi=300)
plt.show()

# %%
MBDF_global_atom = [254.11500261976727, 238.1328641186009, 186.90563407277568, 145.4709306551047, 128.47104308013488]
MBDF_global_atom_err = [92, 72, 35, 15,  6]

MBDF_local_atom = [158.77594153128908, 152.8608612484898, 132.2585742647864, 112.99252974548612, 108.77644891667948]
MBDF_local_atom_err = [ 9, 12,  8,  4,  2]

CSE_lexi_atom = [215.9759249711623, 204.96580609614466, 152.51885686326744, 121.2578461906418, 110.84918910049853]
CSE_lexi_atom_err = [60, 58, 26, 10,  5]

IDM_lexi_atom = [276.1847646131795, 252.47845494525666, 155.95114321087968, 121.8934483567562, 109.04959356256403]
IDM_lexi_atom_err = [110,  83,  26,   9,   6]

# %%
# CSE_lexi
# IDM_lexi
# MBDF_global
# MBDF_local
# Second order alchemy

plt.figure(figsize=(12, 8))


x = [80, 160, 320, 640, 1280]
second_order_alchemy = [145.62546462994108] * 5

linewidth = 3
markersize = 15

plt.plot(x, MBDF_global_atom, label='MBDF Global', marker='*', linestyle='--', linewidth=linewidth, markersize=markersize)
plt.fill_between(x, 
                 np.array(MBDF_global_atom)-np.array(MBDF_global_atom_err), 
                 np.array(MBDF_global_atom)+np.array(MBDF_global_atom_err), alpha=0.2)

plt.plot(x, MBDF_local_atom, label='MBDF Local', marker='*', linestyle='--', linewidth=linewidth, markersize=markersize)
plt.fill_between(x, 
                 np.array(MBDF_local_atom)-np.array(MBDF_local_atom_err), 
                 np.array(MBDF_local_atom)+np.array(MBDF_local_atom_err), alpha=0.2)

plt.plot(x, CSE_lexi_atom, label='CSE-lexi', marker='*', linestyle='-', linewidth=linewidth, markersize=markersize)
plt.fill_between(x, 
                 np.array(CSE_lexi_atom)-np.array(CSE_lexi_atom_err), 
                 np.array(CSE_lexi_atom)+np.array(CSE_lexi_atom_err), alpha=0.2)

plt.plot(x, IDM_lexi_atom, label='IDM-lexi', marker='*', linestyle='-', linewidth=linewidth, markersize=markersize, color='#9467bd')
plt.fill_between(x, 
                 np.array(IDM_lexi_atom)-np.array(IDM_lexi_atom_err), 
                 np.array(IDM_lexi_atom)+np.array(IDM_lexi_atom_err), alpha=0.2)

plt.plot(x, second_order_alchemy, label="Second order alchemy", marker='', linestyle='-', linewidth=linewidth, markersize=markersize, color='red')

# plt.title('Learning curve for BN-Doped Coronene molecule total energy prediction')
plt.xlabel('Training Size')
plt.ylabel('Average MAE [mHa]')
plt.legend()

plt.xscale('log', base=2)
plt.yscale('log', base=10)
xticks = [80, 160, 320, 640, 1280]
yticks = [100, 200, 500, 1000, 2000, 5000, 10000]
plt.xticks(xticks, labels = xticks)
plt.yticks(yticks, labels = yticks)

plt.savefig('../graph/[Coronene] Electronic Energy.png', dpi=300)
plt.show()
